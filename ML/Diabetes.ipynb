# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import pickle as pkl

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# - There are no null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# - Statistical analysis of the data

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
target_vals = df['Outcome'].value_counts()
target_vals
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# - 0 --> Non-diabetic patients
# - 1 --> Diabetic patients

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# - Above table shows that the mean of all the features is higher for diabetic patients than non-diabetic patients. This means that the diabetic patients have higher values of all the features than non-diabetic patients.
#
# - Moreover, people with diabetes have much higher value of glucose and insulin than people without diabetes.

# %%
plt.figure(figsize=(9, 7))
sns.heatmap(df.corr(), annot=True, fmt='.2%')
# Out:
# <Axes: >

# %% [markdown]
# - All the columns are moderately correlated

# %%
print("Percentage of patients without diabetes: " , round(target_vals[0]/len(df.Outcome), 2)*100)
print("Percentage of patients with diabetes: " , round(target_vals[1]/len(df.Outcome), 2)*100)
# Out:
# Percentage of patients without diabetes:  65.0
# Percentage of patients with diabetes:  35.0

# %% [markdown]
# - Separating data and labels

# %%
x = df.drop(columns='Outcome', axis = 1)
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y = df['Outcome']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# - Data Standardization

# %%
scalar = StandardScaler()

# %%
scalar.fit(x)
# Out:
# StandardScaler()

# %%
standardized_data = scalar.transform(x)
standardized_data
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
pkl.dump(scalar, open('scaler.pkl', 'wb'))
scalar
# Out:
# StandardScaler()

# %%
X = standardized_data
Y = df['Outcome']

# %% [markdown]
# - train test split

# %%
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size = 0.2, stratify=y, random_state = 2)

# %%
train_x.shape
# Out:
# (614, 8)

# %%
test_x.shape
# Out:
# (154, 8)

# %%
train_y.shape
# Out:
# (614,)

# %%
test_y.shape
# Out:
# (154,)

# %% [markdown]
# - Model Training

# %% [markdown]
# - LOGISTIC REGRESSION

# %%
lr = LogisticRegression()
lr = lr.fit(train_x, train_y)
lr
# Out:
# LogisticRegression()

# %%
logistic_train_pred = lr.predict(train_x)
logistic_test_pred = lr.predict(test_x)

# %%
print("Logistic Regression Training Accuracy: ", round(accuracy_score(train_y, logistic_train_pred), 2)*100)
print("Logistic Regression Testing Accuracy: ", round(accuracy_score(test_y, logistic_test_pred), 2)*100)
# Out:
# Logistic Regression Training Accuracy:  79.0
# Logistic Regression Testing Accuracy:  76.0

# %%
#pkl.dump(lr, open('lr.pkl', 'wb'))
# lr

# %% [markdown]
# - KNN

# %%
knn = KNeighborsClassifier(n_neighbors=50)
knn.fit(train_x, train_y)
# Out:
# KNeighborsClassifier(n_neighbors=50)

# %%
knn_train_pred = knn.predict(train_x)
knn_test_pred = knn.predict(test_x)

# %%
print("KNN Training Accuracy: ", round(accuracy_score(train_y, knn_train_pred), 2)*100)
print("KNN Testing Accuracy: ", round(accuracy_score(test_y, knn_test_pred), 2)*100)
# Out:
# KNN Training Accuracy:  77.0
# KNN Testing Accuracy:  73.0

# %% [markdown]
# - Decision Trees

# %%
max_accuracy = 0
for i in range(2000):
    clf = DecisionTreeClassifier(random_state = i)
    clf.fit(train_x, train_y)
    pred = clf.predict(test_x)
    current_accuracy = round(accuracy_score(pred, test_y)*100,2)
    if(current_accuracy > max_accuracy):
        max_accuracy = current_accuracy
        best_random_state = i

# print("Best Random State: ", best_random_state)
# print("Best Accuracy: ", max_accuracy)

clf = DecisionTreeClassifier(random_state = best_random_state)
clf.fit(train_x, train_y)
# Out:
# DecisionTreeClassifier(random_state=91)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.453125, 0.96875, 'x[1] <= 0.207\ngini = 0.454\nsamples = 614\nvalue = [400, 214]'),
#  Text(0.20545212765957446, 0.90625, 'x[7] <= -0.403\ngini = 0.296\nsamples = 388\nvalue = [318, 70]'),
#  Text(0.10638297872340426, 0.84375, 'x[5] <= 1.702\ngini = 0.151\nsamples = 219\nvalue = [201, 18]'),
#  Text(0.0851063829787234, 0.78125, 'x[0] <= 1.085\ngini = 0.13\nsamples = 215\nvalue = [200, 15]'),
#  Text(0.07446808510638298, 0.71875, 'x[5] <= -0.132\ngini = 0.122\nsamples = 214\nvalue = [200, 14]'),
#  Text(0.02127659574468085, 0.65625, 'x[6] <= 0.592\ngini = 0.016\nsamples = 122\nvalue = [121, 1]'),
#  Text(0.010638297872340425, 0.59375, 'gini = 0.0\nsamples = 106\nvalue = [106, 0]'),
#  Text(0.031914893617021274, 0.59375, 'x[6] <= 0.648\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.02127659574468085, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0425531914893617, 0.53125, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.1276595744680851, 0.65625, 'x[6] <= 0.573\ngini = 0.243\nsamples = 92\nvalue = [79, 13]'),
#  Text(0.07446808510638298, 0.59375, 'x[5] <= -0.113\ngini = 0.169\nsamples = 75\nvalue = [68, 7]'),
#  Text(0.06382978723404255, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0851063829787234, 0.53125, 'x[2] <= -2.435\ngini = 0.149\nsamples = 74\nvalue = [68, 6]'),
#  Text(0.07446808510638298, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09574468085106383, 0.46875, 'x[4] <= -0.615\ngini = 0.128\nsamples = 73\nvalue = [68, 5]'),
#  Text(0.07446808510638298, 0.40625, 'x[3] <= 1.158\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(0.06382978723404255, 0.34375, 'x[1] <= -0.451\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.05319148936170213, 0.28125, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.07446808510638298, 0.28125, 'x[5] <= 0.318\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.06382978723404255, 0.21875, 'x[2] <= -0.161\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.05319148936170213, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07446808510638298, 0.15625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.0851063829787234, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0851063829787234, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11702127659574468, 0.40625, 'x[0] <= 0.194\ngini = 0.036\nsamples = 55\nvalue = [54, 1]'),
#  Text(0.10638297872340426, 0.34375, 'gini = 0.0\nsamples = 52\nvalue = [52, 0]'),
#  Text(0.1276595744680851, 0.34375, 'x[2] <= -0.109\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.11702127659574468, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13829787234042554, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.18085106382978725, 0.59375, 'x[1] <= -0.075\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.1702127659574468, 0.53125, 'x[4] <= -0.142\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.14893617021276595, 0.46875, 'x[7] <= -0.956\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.13829787234042554, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1595744680851064, 0.40625, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.19148936170212766, 0.46875, 'x[5] <= 0.033\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.18085106382978725, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20212765957446807, 0.40625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.19148936170212766, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.09574468085106383, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1276595744680851, 0.78125, 'x[6] <= 0.653\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.11702127659574468, 0.71875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.13829787234042554, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3045212765957447, 0.84375, 'x[1] <= -0.638\ngini = 0.426\nsamples = 169\nvalue = [117, 52]'),
#  Text(0.24468085106382978, 0.78125, 'x[6] <= 2.142\ngini = 0.194\nsamples = 55\nvalue = [49, 6]'),
#  Text(0.23404255319148937, 0.71875, 'x[0] <= 2.867\ngini = 0.168\nsamples = 54\nvalue = [49, 5]'),
#  Text(0.22340425531914893, 0.65625, 'x[1] <= -2.892\ngini = 0.14\nsamples = 53\nvalue = [49, 4]'),
#  Text(0.2127659574468085, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23404255319148937, 0.59375, 'x[3] <= 0.625\ngini = 0.109\nsamples = 52\nvalue = [49, 3]'),
#  Text(0.22340425531914893, 0.53125, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.24468085106382978, 0.53125, 'x[3] <= 0.75\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.23404255319148937, 0.46875, 'x[4] <= 0.249\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.22340425531914893, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.24468085106382978, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2553191489361702, 0.46875, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.24468085106382978, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2553191489361702, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36436170212765956, 0.78125, 'x[5] <= -0.716\ngini = 0.481\nsamples = 114\nvalue = [68, 46]'),
#  Text(0.3191489361702128, 0.71875, 'x[5] <= -2.817\ngini = 0.091\nsamples = 21\nvalue = [20, 1]'),
#  Text(0.30851063829787234, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32978723404255317, 0.65625, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.4095744680851064, 0.71875, 'x[6] <= 0.269\ngini = 0.499\nsamples = 93\nvalue = [48, 45]'),
#  Text(0.35106382978723405, 0.65625, 'x[2] <= -0.109\ngini = 0.475\nsamples = 67\nvalue = [41, 26]'),
#  Text(0.30851063829787234, 0.59375, 'x[2] <= -0.574\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.2872340425531915, 0.53125, 'x[1] <= -0.106\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2765957446808511, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2978723404255319, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32978723404255317, 0.53125, 'x[6] <= -0.14\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.3191489361702128, 0.46875, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.3404255319148936, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39361702127659576, 0.59375, 'x[5] <= 1.41\ngini = 0.42\nsamples = 50\nvalue = [35, 15]'),
#  Text(0.3829787234042553, 0.53125, 'x[5] <= 0.331\ngini = 0.38\nsamples = 47\nvalue = [35, 12]'),
#  Text(0.3617021276595745, 0.46875, 'x[2] <= 1.029\ngini = 0.471\nsamples = 29\nvalue = [18, 11]'),
#  Text(0.35106382978723405, 0.40625, 'x[7] <= 1.937\ngini = 0.497\nsamples = 24\nvalue = [13, 11]'),
#  Text(0.3404255319148936, 0.34375, 'x[2] <= 0.305\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.3191489361702128, 0.28125, 'x[5] <= -0.551\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.30851063829787234, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.32978723404255317, 0.21875, 'x[3] <= 0.468\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.3191489361702128, 0.15625, 'x[1] <= -0.451\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.30851063829787234, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.32978723404255317, 0.09375, 'x[6] <= -0.652\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3191489361702128, 0.03125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3404255319148936, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3404255319148936, 0.15625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3617021276595745, 0.28125, 'x[6] <= -0.154\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.35106382978723405, 0.21875, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3723404255319149, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3617021276595745, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3723404255319149, 0.40625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.40425531914893614, 0.46875, 'x[0] <= -0.845\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.39361702127659576, 0.40625, 'x[5] <= 0.477\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3829787234042553, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.40425531914893614, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4148936170212766, 0.40625, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.40425531914893614, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.46808510638297873, 0.65625, 'x[0] <= 0.788\ngini = 0.393\nsamples = 26\nvalue = [7, 19]'),
#  Text(0.4574468085106383, 0.59375, 'x[3] <= 0.217\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.43617021276595747, 0.53125, 'x[1] <= -0.466\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.425531914893617, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.44680851063829785, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4787234042553192, 0.53125, 'x[6] <= 2.788\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.46808510638297873, 0.46875, 'x[4] <= 1.261\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.4574468085106383, 0.40625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4787234042553192, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.48936170212765956, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4787234042553192, 0.59375, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.7007978723404256, 0.90625, 'x[5] <= -0.259\ngini = 0.462\nsamples = 226\nvalue = [82, 144]'),
#  Text(0.5585106382978723, 0.84375, 'x[7] <= 2.362\ngini = 0.452\nsamples = 55\nvalue = [36, 19]'),
#  Text(0.5478723404255319, 0.78125, 'x[1] <= 0.958\ngini = 0.482\nsamples = 47\nvalue = [28, 19]'),
#  Text(0.5212765957446809, 0.71875, 'x[2] <= -0.678\ngini = 0.4\nsamples = 29\nvalue = [21, 8]'),
#  Text(0.5106382978723404, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5319148936170213, 0.65625, 'x[5] <= -0.488\ngini = 0.346\nsamples = 27\nvalue = [21, 6]'),
#  Text(0.5106382978723404, 0.59375, 'x[7] <= 2.149\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.5, 0.53125, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.5212765957446809, 0.53125, 'x[6] <= -0.128\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5106382978723404, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5319148936170213, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5531914893617021, 0.59375, 'x[0] <= -0.102\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.5425531914893617, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5638297872340425, 0.53125, 'x[7] <= 0.533\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.5531914893617021, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.574468085106383, 0.46875, 'x[5] <= -0.291\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5638297872340425, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5851063829787234, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.574468085106383, 0.71875, 'x[7] <= -0.659\ngini = 0.475\nsamples = 18\nvalue = [7, 11]'),
#  Text(0.5638297872340425, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5851063829787234, 0.65625, 'x[5] <= -0.621\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.574468085106383, 0.59375, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.5957446808510638, 0.59375, 'x[7] <= 0.277\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.5851063829787234, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6063829787234043, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5691489361702128, 0.78125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.8430851063829787, 0.84375, 'x[1] <= 1.396\ngini = 0.393\nsamples = 171\nvalue = [46, 125]'),
#  Text(0.723404255319149, 0.78125, 'x[7] <= -0.233\ngini = 0.454\nsamples = 115\nvalue = [40, 75]'),
#  Text(0.6595744680851063, 0.71875, 'x[2] <= -0.419\ngini = 0.5\nsamples = 47\nvalue = [24, 23]'),
#  Text(0.648936170212766, 0.65625, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.6702127659574468, 0.65625, 'x[4] <= 1.5\ngini = 0.456\nsamples = 37\nvalue = [24, 13]'),
#  Text(0.6595744680851063, 0.59375, 'x[5] <= 1.232\ngini = 0.5\nsamples = 26\nvalue = [13, 13]'),
#  Text(0.6382978723404256, 0.53125, 'x[1] <= 1.052\ngini = 0.465\nsamples = 19\nvalue = [12, 7]'),
#  Text(0.6276595744680851, 0.46875, 'x[5] <= 0.001\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.6063829787234043, 0.40625, 'x[7] <= -0.488\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5957446808510638, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6170212765957447, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.648936170212766, 0.40625, 'x[1] <= 0.332\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.6382978723404256, 0.34375, 'x[7] <= -0.871\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6276595744680851, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.648936170212766, 0.28125, 'x[5] <= 0.096\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6382978723404256, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6595744680851063, 0.21875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6595744680851063, 0.34375, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.648936170212766, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6808510638297872, 0.53125, 'x[3] <= 1.848\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6702127659574468, 0.46875, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6914893617021277, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6808510638297872, 0.59375, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.7872340425531915, 0.71875, 'x[6] <= -0.128\ngini = 0.36\nsamples = 68\nvalue = [16, 52]'),
#  Text(0.7340425531914894, 0.65625, 'x[1] <= 0.301\ngini = 0.48\nsamples = 30\nvalue = [12, 18]'),
#  Text(0.723404255319149, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7446808510638298, 0.59375, 'x[5] <= 0.274\ngini = 0.444\nsamples = 27\nvalue = [9, 18]'),
#  Text(0.723404255319149, 0.53125, 'x[2] <= 1.029\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.7127659574468085, 0.46875, 'x[3] <= -0.818\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.7021276595744681, 0.40625, 'x[5] <= 0.134\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6914893617021277, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7127659574468085, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.723404255319149, 0.40625, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.7340425531914894, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7659574468085106, 0.53125, 'x[6] <= -0.673\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.7553191489361702, 0.46875, 'x[6] <= -0.697\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.7446808510638298, 0.40625, 'x[7] <= 1.128\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.7340425531914894, 0.34375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7553191489361702, 0.34375, 'x[6] <= -0.91\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7446808510638298, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7659574468085106, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7659574468085106, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.776595744680851, 0.46875, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8404255319148937, 0.65625, 'x[4] <= 2.203\ngini = 0.188\nsamples = 38\nvalue = [4, 34]'),
#  Text(0.8191489361702128, 0.59375, 'x[1] <= 1.365\ngini = 0.108\nsamples = 35\nvalue = [2, 33]'),
#  Text(0.8085106382978723, 0.53125, 'x[0] <= 2.57\ngini = 0.057\nsamples = 34\nvalue = [1, 33]'),
#  Text(0.7978723404255319, 0.46875, 'gini = 0.0\nsamples = 32\nvalue = [0, 32]'),
#  Text(0.8191489361702128, 0.46875, 'x[7] <= 0.83\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8085106382978723, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8297872340425532, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8297872340425532, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8617021276595744, 0.59375, 'x[2] <= -0.264\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.851063829787234, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8723404255319149, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9627659574468085, 0.78125, 'x[0] <= 1.679\ngini = 0.191\nsamples = 56\nvalue = [6, 50]'),
#  Text(0.9521276595744681, 0.71875, 'x[4] <= 5.051\ngini = 0.165\nsamples = 55\nvalue = [5, 50]'),
#  Text(0.925531914893617, 0.65625, 'x[7] <= 2.064\ngini = 0.14\nsamples = 53\nvalue = [4, 49]'),
#  Text(0.9042553191489362, 0.59375, 'x[6] <= -0.499\ngini = 0.081\nsamples = 47\nvalue = [2, 45]'),
#  Text(0.8936170212765957, 0.53125, 'x[6] <= -0.617\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.8829787234042553, 0.46875, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9042553191489362, 0.46875, 'x[0] <= -0.548\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8936170212765957, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9148936170212766, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9148936170212766, 0.53125, 'gini = 0.0\nsamples = 35\nvalue = [0, 35]'),
#  Text(0.9468085106382979, 0.59375, 'x[1] <= 1.85\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.9361702127659575, 0.53125, 'x[4] <= 1.76\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.925531914893617, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9468085106382979, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9574468085106383, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9787234042553191, 0.65625, 'x[7] <= 1.001\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9680851063829787, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9893617021276596, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.973404255319149, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
decision_train_pred = clf.predict(train_x)
decision_test_pred = clf.predict(test_x)

# %%
print("Decision Tree Training Accuracy: ", round(accuracy_score(train_y, decision_train_pred), 2)*100)
print("Decision Tree Testing Accuracy: ", round(accuracy_score(test_y, decision_test_pred), 2)*100)
# Out:
# Decision Tree Training Accuracy:  100.0
# Decision Tree Testing Accuracy:  73.0

# %% [markdown]
# - Random Forest

# %%
rf = RandomForestClassifier(n_estimators=500, random_state = best_random_state)

# %%
rf.fit(train_x, train_y)
# Out:
# RandomForestClassifier(n_estimators=500, random_state=91)

# %%
rf_train_pred = rf.predict(train_x)
rf_test_pred = rf.predict(test_x)

# %%
print("Random Forest Training Accuracy: ", round(accuracy_score(train_y, rf_train_pred), 2)*100)
print("Random Forest Testing Accuracy: ", round(accuracy_score(test_y, rf_test_pred), 2)*100)
# Out:
# Random Forest Training Accuracy:  100.0
# Random Forest Testing Accuracy:  73.0

# %% [markdown]
# - SVM

# %%
classifier = SVC(kernel = 'linear')
classifier.fit(train_x, train_y)
# Out:
# SVC(kernel='linear')

# %%
print("SVM Training Accuracy: ", round(classifier.score(train_x, train_y)*100, 2))
print("SVM Testing Accuracy: ", round(classifier.score(test_x, test_y)*100, 2))
# Out:
# SVM Training Accuracy:  78.66
# SVM Testing Accuracy:  77.27

# %% [markdown]
# Deep Learing
# *simple feedforward neural network

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler

# %%
# Example: Let's assume train_y and test_y are not one-hot encoded
num_classes = len(np.unique(train_y))
train_y = to_categorical(train_y, num_classes)
test_y = to_categorical(test_y, num_classes)

# %%
# Feature scaling
scaler = StandardScaler()
train_X = scaler.fit_transform(train_x)
test_X = scaler.transform(test_x)

# %%
model = Sequential()
model.add(Dense(64, input_dim=train_x.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8643 - loss: 0.2916 - val_accuracy: 0.7078 - val_loss: 0.6520
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8668 - loss: 0.3193 - val_accuracy: 0.7078 - val_loss: 0.6392
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8697 - loss: 0.3131 - val_accuracy: 0.7013 - val_loss: 0.6438
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8724 - loss: 0.3007 - val_accuracy: 0.7208 - val_loss: 0.6594
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8810 - loss: 0.3106 - val_accuracy: 0.7078 - val_loss: 0.6611
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8842 - loss: 0.2813 - val_accuracy: 0.7013 - val_loss: 0.6826
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8657 - loss: 0.3159 - val_accuracy: 0.7143 - val_loss: 0.6589
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8943 - loss: 0.2723 - val_accuracy: 0.7208 - val_loss: 0.6773
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8718 - loss: 0.2756 - val_accuracy: 0.7143 - val_loss: 0.6890
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9024 - loss: 0.2644 - val_accuracy: 0.7013 - val_loss: 0.6997
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8958 - loss: 0.2589 - val_accuracy: 0.7078 - val_loss: 0.6940
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8935 - loss: 0.2746 - val_accuracy: 0.7078 - val_loss: 0.7084
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8982 - loss: 0.2679 - val_accuracy: 0.6948 - val_loss: 0.7219
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8911 - loss: 0.2972 - val_accuracy: 0.7078 - val_loss: 0.7243
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8854 - loss: 0.2830 - val_accuracy: 0.7078 - val_loss: 0.7249

# %%
# Evaluate the model
train_loss, train_accuracy = model.evaluate(train_X, train_y)
test_loss, test_accuracy = model.evaluate(test_X, test_y)

print(f'Training Accuracy: {train_accuracy * 100:.2f}%')
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
#overfitting  model .........learning to much at time of training but not at the time of testing
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9001 - loss: 0.2655
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7251 - loss: 0.7226
# Training Accuracy: 90.55%
# Test Accuracy: 70.78%

# %%
#using regularization , dropout , earlystoppinng for overfitting
# Build the model with regularization and dropout
model = Sequential()
model.add(Dense(64, input_dim=train_X.shape[1], activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.005)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Use EarlyStopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(train_X, train_y, epochs=150, batch_size=20, validation_data=(test_X, test_y), callbacks=[early_stopping])
# Out:
# Epoch 1/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5392 - loss: 1.1005 - val_accuracy: 0.6753 - val_loss: 0.8742
# Epoch 2/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6716 - loss: 0.9153 - val_accuracy: 0.7273 - val_loss: 0.8151
# Epoch 3/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7330 - loss: 0.8383 - val_accuracy: 0.7532 - val_loss: 0.7753
# Epoch 4/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7247 - loss: 0.7785 - val_accuracy: 0.7597 - val_loss: 0.7495
# Epoch 5/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7406 - loss: 0.7586 - val_accuracy: 0.7792 - val_loss: 0.7232
# Epoch 6/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7573 - loss: 0.7376 - val_accuracy: 0.7727 - val_loss: 0.7097
# Epoch 7/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7746 - loss: 0.6788 - val_accuracy: 0.7792 - val_loss: 0.6940
# Epoch 8/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7457 - loss: 0.6827 - val_accuracy: 0.7727 - val_loss: 0.6836
# Epoch 9/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7535 - loss: 0.6583 - val_accuracy: 0.7597 - val_loss: 0.6760
# Epoch 10/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7542 - loss: 0.6438 - val_accuracy: 0.7662 - val_loss: 0.6645
# Epoch 11/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 0.6849 - val_accuracy: 0.7727 - val_loss: 0.6532
# Epoch 12/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7889 - loss: 0.4560 - val_accuracy: 0.7468 - val_loss: 0.5496
# Epoch 76/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7766 - loss: 0.4849 - val_accuracy: 0.7468 - val_loss: 0.5495
# Epoch 77/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7928 - loss: 0.4811 - val_accuracy: 0.7597 - val_loss: 0.5451
# Epoch 78/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7784 - loss: 0.4523 - val_accuracy: 0.7468 - val_loss: 0.5445
# Epoch 79/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8190 - loss: 0.4564 - val_accuracy: 0.7403 - val_loss: 0.5459
# Epoch 80/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7863 - loss: 0.4774 - val_accuracy: 0.7532 - val_loss: 0.5546
# Epoch 81/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7914 - loss: 0.4587 - val_accuracy: 0.7403 - val_loss: 0.5515
# Epoch 82/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8140 - loss: 0.4505 - val_accuracy: 0.7532 - val_loss: 0.5515
# Epoch 83/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7850 - loss: 0.4522 - val_accuracy: 0.7338 - val_loss: 0.5522
# Epoch 84/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8186 - loss: 0.4186 - val_accuracy: 0.7662 - val_loss: 0.5582

# %%
# Evaluate the model
train_loss, train_accuracy = model.evaluate(train_X, train_y)
test_loss, test_accuracy = model.evaluate(test_X, test_y)

print(f'Training Accuracy: {train_accuracy * 100:.2f}%')
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8005 - loss: 0.4332
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8004 - loss: 0.4335
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7485 - loss: 0.5488
# Training Accuracy: 80.13%
# Test Accuracy: 73.38%

# %%
# Save the model
model.save("neural_network.keras")

# %%
input_data = (10,139,80,0,0,27.1,1.441,57)
data = np.array(input_data)
data
# Out:
# array([ 10.   , 139.   ,  80.   ,   0.   ,   0.   ,  27.1  ,   1.441,
#         57.   ])

# %%
std_data = scalar.transform(data.reshape(1, -1))
# Out:
# /Users/apple/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = rf.predict(std_data)
prediction
# Out:
# array([0])

# %%
if prediction == 1:
    print("The patient has diabetes")
else:
    print("The patient does not have diabetes")
# Out:
# The patient does not have diabetes

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
fig, ax = plt.subplots(4, 2, figsize=(20, 25))
plt.style.use('ggplot')

sns.histplot(x = df['Age'], hue = df['Outcome'], palette="viridis",kde = True, ax = ax[0, 0])
ax[0,0].set_xlabel('Age', fontsize = 15)

sns.histplot(x = df['BMI'], hue = df['Outcome'], palette="viridis",kde = True, ax = ax[0, 1])
ax[0,1].set_xlabel('BMI', fontsize = 15)


sns.histplot(x = df['BloodPressure'], hue = df['Outcome'], palette="dark",kde = True, ax = ax[1, 0])
ax[1,0].set_xlabel('BloodPressure', fontsize = 15)

sns.histplot(x = df['DiabetesPedigreeFunction'], hue = df['Outcome'], palette="dark",kde = True, ax = ax[1, 1])
ax[1,1].set_xlabel('DiabetesPedigreeFunction', fontsize = 15)


sns.histplot(x = df['Glucose'], hue = df['Outcome'], palette="flare",kde = True, ax = ax[2, 0])
ax[2,0].set_xlabel('Glucose', fontsize = 15)

sns.histplot(x = df['Insulin'], hue = df['Outcome'], palette="flare",kde = True, ax = ax[2, 1])
ax[2,1].set_xlabel('Insulin', fontsize = 15)


sns.histplot(x = df['Pregnancies'], hue = df['Outcome'], palette="viridis",kde = True, ax = ax[3, 0])
ax[3,0].set_xlabel('Pregnancies', fontsize = 15)

sns.histplot(x = df['SkinThickness'], hue = df['Outcome'], palette="viridis",kde = True, ax = ax[3, 1])
ax[3,1].set_xlabel('SkinThickness', fontsize = 15)
# Out:
# Text(0.5, 0, 'SkinThickness')

# %%
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size = 0.2, stratify=y, random_state = 2)

# %%
cf_matrix = confusion_matrix(test_y, rf_test_pred)
cf_matrix

# Order: TN, FP, FN, TP
# Out:
# array([[87, 13],
#        [28, 26]])

# %%
tn, fp, fn, tp = cf_matrix.ravel()
print(tn, fp, fn, tp)

# Ravel function is used to extract the confusion matrix values
# Out:
# 87 13 28 26

# %%
sns.heatmap(cf_matrix, annot=True)

# Annot displays labels
# Out:
# <Axes: >

# %%
precision_recall_fscore_support(test_y, rf_test_pred, average = 'macro')
# Out:
# (0.7115942028985507, 0.6757407407407408, 0.6842210552638159, None)

# %%
#pkl.dump(rf, open('nb.pkl', 'wb'))
# nb

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# Plot for Age
plt.figure(figsize=(8, 4))
sns.histplot(x=df['Age'], hue=df['Outcome'], palette="viridis", kde=True)
plt.xlabel('Age', fontsize=15)
plt.title('Age Distribution by Outcome')
plt.show()

# Plot for BMI
plt.figure(figsize=(8, 4))
sns.histplot(x=df['BMI'], hue=df['Outcome'], palette="viridis", kde=True)
plt.xlabel('BMI', fontsize=15)
plt.title('BMI Distribution by Outcome')
plt.show()

# Plot for BloodPressure
plt.figure(figsize=(8, 4))
sns.histplot(x=df['BloodPressure'], hue=df['Outcome'], palette="dark", kde=True)
plt.xlabel('BloodPressure', fontsize=15)
plt.title('Blood Pressure Distribution by Outcome')
plt.show()

# Plot for DiabetesPedigreeFunction
plt.figure(figsize=(8,4))
sns.histplot(x=df['DiabetesPedigreeFunction'], hue=df['Outcome'], palette="dark", kde=True)
plt.xlabel('DiabetesPedigreeFunction', fontsize=15)
plt.title('Diabetes Pedigree Function Distribution by Outcome')
plt.show()

# Plot for Glucose
plt.figure(figsize=(8,4))
sns.histplot(x=df['Glucose'], hue=df['Outcome'], palette="flare", kde=True)
plt.xlabel('Glucose', fontsize=15)
plt.title('Glucose Distribution by Outcome')
plt.show()

# Plot for Insulin
plt.figure(figsize=(8,4))
sns.histplot(x=df['Insulin'], hue=df['Outcome'], palette="flare", kde=True)
plt.xlabel('Insulin', fontsize=15)
plt.title('Insulin Distribution by Outcome')
plt.show()

# Plot for Pregnancies
plt.figure(figsize=(8,4))
sns.histplot(x=df['Pregnancies'], hue=df['Outcome'], palette="viridis", kde=True)
plt.xlabel('Pregnancies', fontsize=15)
plt.title('Pregnancies Distribution by Outcome')
plt.show()

# Plot for SkinThickness
plt.figure(figsize=(8,4))
sns.histplot(x=df['SkinThickness'], hue=df['Outcome'], palette="viridis", kde=True)
plt.xlabel('SkinThickness', fontsize=15)
plt.title('Skin Thickness Distribution by Outcome')
plt.show()
